# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numbers
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd /home/jhcharles/code/jhcharles/sunny_britain
# Out:
# /home/jhcharles/code/jhcharles/sunny_britain

# %%
from sunny_britain.data import Inverter

# %%
pwd
# Out:
# '/home/jhcharles/code/jhcharles/sunny_britain/sunny_britain'

# %%
Inverter().get_data()
# Out:
# {'Site 1_':                   Timestamp  Power Inverter AC (kW) [Inverter 1]  \
# 0       2017-01-01 00:15:00                                  0.0
# 1       2017-01-01 00:30:00                                  0.0
# 2       2017-01-01 00:45:00                                  0.0
# 3       2017-01-01 01:00:00                                  0.0
# 4       2017-01-01 01:15:00                                  0.0
# ...                     ...                                  ...
# 171067  2021-11-17 23:00:00                                  0.0
# 171068  2021-11-17 23:15:00                                  0.0
# 171069  2021-11-17 23:30:00                                  0.0
# 171070  2021-11-17 23:45:00                                  0.0
# 171071  2021-11-18 00:00:00                                  0.0
#
#         Power Inverter AC (kW) [Inverter 2]  \
# 0                                       0.0
# 1                                       0.0
# ...

# %%
events = pd.read_csv('../raw_data/Events data 2017 - 2021.csv')

# %%
metadata = pd.read_csv('../raw_data/Metadata.csv')

# %%
events.head()

# %%
events.groupby(['Category']).count()[['Status','Outage']]

# %%
events = pd.DataFrame(events)

# %%
site_34 = pd.read_csv('../raw_data/Site 34 Inverters data-20170101T000000.csv')

# %%
site_34.columns

# %%
site_34.dtypes

# %%
site_34['datetime'] = pd.to_datetime(site_34['Timestamp'])

# %%
sns.histplot(site_34['Power Inverter AC (kW) [Inverter 1]'])

# %%
unavailability = site_34[['Timestamp', 'Availability (%) [Inverter 1]', 'Availability (%) [Inverter 2]']]

# %%
number_zeros = site_34[['Timestamp', 'Availability (%) [Inverter 1]']][unavailability['Availability (%) [Inverter 1]'] == 0]

# %%
len(site_34)

# %%
int(len(number_zeros))/ int(len(site_34))*100
